# %%
import pandas as pd
df = pd.read_csv("/media/julie/Home/BotLab/DevOPs/pandas/DataMarketWeather.csv")
df
# Out:
#       Location ID        Country                City ElevationUnit  Elevation  \
# 0             656          CHINA           Hong Kong        meters        8.0
# 1             657          CHINA                Mohe        meters      433.0
# 2             658          CHINA                Huma        meters      179.0
# 3             659          CHINA              Tulihe        meters      733.0
# 4             660          CHINA               Heihe        meters      166.0
# 5             661          CHINA              Hailar        meters      611.0
# 6             662          CHINA            Nenjiang        meters      243.0
# 7             663          CHINA               Sunwu        meters      235.0
# 8             664          CHINA          Altan Emel        meters      556.0
# 9             665          CHINA                Bugt        meters      739.0
# 10            666          CHINA              Keshan        meters      237.0
# ...

# %%
df.shape #is a tuple
# Out:
# (3962, 9)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 3962

# %%
columns
# Out:
# 9

# %%
df.head() #prints a few first rows
# Out:
#    Location ID Country       City ElevationUnit  Elevation  Latitude  \
# 0          656   CHINA  Hong Kong        meters        8.0    22.317
# 1          657   CHINA       Mohe        meters      433.0    52.133
# 2          658   CHINA       Huma        meters      179.0    51.717
# 3          659   CHINA     Tulihe        meters      733.0    50.450
# 4          660   CHINA      Heihe        meters      166.0    50.250
#
#    Longitude StateAbbreviation StateName
# 0    113.917               NaN       NaN
# 1    122.517               NaN       NaN
# 2    126.650               NaN       NaN
# 3    121.700               NaN       NaN
# 4    127.450               NaN       NaN

# %%
df.head(3) #prints first three rows
# Out:
#    Location ID Country       City ElevationUnit  Elevation  Latitude  \
# 0          656   CHINA  Hong Kong        meters        8.0    22.317
# 1          657   CHINA       Mohe        meters      433.0    52.133
# 2          658   CHINA       Huma        meters      179.0    51.717
#
#    Longitude StateAbbreviation StateName
# 0    113.917               NaN       NaN
# 1    122.517               NaN       NaN
# 2    126.650               NaN       NaN

# %%
df.tail() #prints the last few rows
# Out:
#       Location ID        Country            City ElevationUnit  Elevation  \
# 3957         3874  UNITED STATES     Hope Estate        meters        3.0
# 3958         3875  UNITED STATES       Annapolis        meters       12.0
# 3959         3876  UNITED STATES   St. Augustine        meters        9.0
# 3960         3877  UNITED STATES  Dauphin Island        meters        9.0
# 3961         3957  UNITED STATES        Waycross        meters       41.0
#
#       Latitude  Longitude StateAbbreviation StateName
# 3957    26.683   -79.0000                FL   FLORIDA
# 3958    38.900   -76.4330                MD  MARYLAND
# 3959    29.867   -81.2670                FL   FLORIDA
# 3960    30.250   -88.0830                AL   ALABAMA
# 3961    31.250   -82.3926                GA   GEORGIA

# %%
df.tail(2)
# Out:
#       Location ID        Country            City ElevationUnit  Elevation  \
# 3960         3877  UNITED STATES  Dauphin Island        meters        9.0
# 3961         3957  UNITED STATES        Waycross        meters       41.0
#
#       Latitude  Longitude StateAbbreviation StateName
# 3960     30.25   -88.0830                AL   ALABAMA
# 3961     31.25   -82.3926                GA   GEORGIA

# %%
df[2:6]
# Out:
#    Location ID Country    City ElevationUnit  Elevation  Latitude  Longitude  \
# 2          658   CHINA    Huma        meters      179.0    51.717     126.65
# 3          659   CHINA  Tulihe        meters      733.0    50.450     121.70
# 4          660   CHINA   Heihe        meters      166.0    50.250     127.45
# 5          661   CHINA  Hailar        meters      611.0    49.217     119.75
#
#   StateAbbreviation StateName
# 2               NaN       NaN
# 3               NaN       NaN
# 4               NaN       NaN
# 5               NaN       NaN

# %%
df[-5:-1]
# Out:
#       Location ID        Country            City ElevationUnit  Elevation  \
# 3957         3874  UNITED STATES     Hope Estate        meters        3.0
# 3958         3875  UNITED STATES       Annapolis        meters       12.0
# 3959         3876  UNITED STATES   St. Augustine        meters        9.0
# 3960         3877  UNITED STATES  Dauphin Island        meters        9.0
#
#       Latitude  Longitude StateAbbreviation StateName
# 3957    26.683    -79.000                FL   FLORIDA
# 3958    38.900    -76.433                MD  MARYLAND
# 3959    29.867    -81.267                FL   FLORIDA
# 3960    30.250    -88.083                AL   ALABAMA

# %%
df.columns
# Out:
# Index(['Location ID', 'Country', 'City', 'ElevationUnit', 'Elevation',
#        'Latitude', 'Longitude', 'StateAbbreviation', 'StateName'],
#       dtype='object')

# %%
df.columns[5]
# Out:
# 'Latitude'

# %%
df.Country[-10:-1]
# Out:
# 3952    UNITED STATES
# 3953    UNITED STATES
# 3954    UNITED STATES
# 3955    UNITED STATES
# 3956    UNITED STATES
# 3957    UNITED STATES
# 3958    UNITED STATES
# 3959    UNITED STATES
# 3960    UNITED STATES
# Name: Country, dtype: object

# %%
df.Latitude[2:11]
# Out:
# 2     51.717
# 3     50.450
# 4     50.250
# 5     49.217
# 6     49.167
# 7     49.433
# 8     48.667
# 9     48.767
# 10    48.050
# Name: Latitude, dtype: float64

# %%
type(df['Latitude'])
# Out:
# pandas.core.series.Series

# %%
df[['Country','Latitude']]
# Out:
#             Country  Latitude
# 0             CHINA    22.317
# 1             CHINA    52.133
# 2             CHINA    51.717
# 3             CHINA    50.450
# 4             CHINA    50.250
# 5             CHINA    49.217
# 6             CHINA    49.167
# 7             CHINA    49.433
# 8             CHINA    48.667
# 9             CHINA    48.767
# 10            CHINA    48.050
# 11            CHINA    47.167
# 12            CHINA    47.383
# 13            CHINA    47.433
# 14            CHINA    47.717
# 15            CHINA    47.233
# 16            CHINA    46.400
# 17            CHINA    46.383
# 18            CHINA    46.317
# 19            CHINA    45.517
# 20            CHINA    45.083
# 21            CHINA    45.750
# 22            CHINA    45.967
# 23            CHINA    45.217
# 24            CHINA    45.283
# 25            CHINA    45.767
# 26            CHINA    48.050
# 27            CHINA    47.733
# 28            CHINA    46.983
# 29            CHINA    46.733
# ...
