# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

kazi = pd.read_csv("/media/julie/Home/BotLab/ikokazi/IkoKaziExtended.csv")
kazi[0:20]
# Out:
#               Timestamp                                         Tweet_text  \
# 0   2019-05-22 08:52:11  Information Technology Intern at Save the Chil...
# 1   2019-05-22 08:50:38  OFFER! OFFER! OFFER! Get websites for corporat...
# 2   2019-05-22 08:28:26  A brother is looking for internship opportunit...
# 3   2019-05-22 07:00:00  #IkoKazi New!! Konza Technopolis Job Opportuni...
# 4   2019-05-22 06:46:53  .#IkoKaziKE Last day to apply... Role: Resourc...
# 5   2019-05-22 06:45:03  We are hiring!! We are looking for a nurse to ...
# 6   2019-05-22 06:26:00  Looking for someone who has a sales and market...
# 7   2019-05-22 06:25:35                  @IEBCKenya @B_E_N_J_A_H  #ikokazi
# 8   2019-05-22 05:49:00  CLOSING TODAY: Applications for Research Assis...
# 9   2019-05-22 05:46:00  CLOSING TODAY: Applications for UN-Habitat Urb...
# 10  2019-05-22 05:32:00  DEADLINE DAY: Applications for UNICEF Youth Ad...
# ...

# %%
kazi.describe()
# Out:
#           followers
# count    332.000000
# mean    6174.216867
# std     8189.760132
# min        1.000000
# 25%      261.000000
# 50%     1403.500000
# 75%    12721.000000
# max    97168.000000

# %%
# usernames with more than 1000 followers
user_1000=kazi[kazi.followers>=1000].drop_duplicates(["username"])
user_1000
# Out:
#                Timestamp                                         Tweet_text  \
# 0    2019-05-22 08:52:11  Information Technology Intern at Save the Chil...
# 3    2019-05-22 07:00:00  #IkoKazi New!! Konza Technopolis Job Opportuni...
# 4    2019-05-22 06:46:53  .#IkoKaziKE Last day to apply... Role: Resourc...
# 6    2019-05-22 06:26:00  Looking for someone who has a sales and market...
# 17   2019-05-22 03:40:42      @EACCKenya #IkoKazi 👇 https://t.co/G3vBiIARRx
# 18   2019-05-22 03:38:37  If you’re a graduate teacher (primary or high ...
# 20   2019-05-21 19:13:43  Imports &amp; Exports Officer Job .Have a Dipl...
# 21   2019-05-21 16:32:03        #IkoKaziKE #IkoKazi https://t.co/M7SrPVPBn6
# 34   2019-05-21 08:59:59  @UNICEFKenya has an open position for a youth ...
# 38   2019-05-21 08:16:19  The job i do, the job i love #tiling #IkoKazi ...
# 40   2019-05-21 06:37:37  National Employment Authority strategic object...
# ...

# %%
# usernames with more than 10000 followers
kazi[kazi.followers>=10000].drop_duplicates(["username"])
# Out:
#                Timestamp                                         Tweet_text  \
# 0    2019-05-22 08:52:11  Information Technology Intern at Save the Chil...
# 3    2019-05-22 07:00:00  #IkoKazi New!! Konza Technopolis Job Opportuni...
# 59   2019-05-20 11:09:18  We’re Hiring!: Content Creator #Ikokazi #ikoka...
# 70   2019-05-20 08:07:26  @AjiraDigital Mon, May 20, 2019, 8:00 AM – Fri...
# 193  2019-05-15 14:48:35  Sonko awarding half-a-million shillings to the...
# 271  2019-05-14 04:22:17                   #IkoKazi https://t.co/XO2ckUd5tM
#
#               username  followers
# 0       b'campusbizKE'      12721
# 3     b'CareerPointKe'      18605
# 59        b'KenyaBuzz'      97168
# 70        b'UwezoFund'      26182
# 193        b'KWALANDA'      36445
# 271  b'fredrick_kavoo'      19190

# %%
# username with the highest followers
kazi[kazi.followers==kazi.followers.max()]
# Out:
#               Timestamp                                         Tweet_text  \
# 59  2019-05-20 11:09:18  We’re Hiring!: Content Creator #Ikokazi #ikoka...
#
#         username  followers
# 59  b'KenyaBuzz'      97168

# %%
# username with the least followers
kazi[kazi.followers==kazi.followers.min()]
# Out:
#              Timestamp                                         Tweet_text  \
# 1  2019-05-22 08:50:38  OFFER! OFFER! OFFER! Get websites for corporat...
#
#              username  followers
# 1  b'JamiiWebdesigns'          1

# %%
uniwe=kazi.duplicated('username')
uniwe
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9       True
# 10      True
# 11     False
# 12     False
# 13      True
# 14     False
# 15      True
# 16      True
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 302     True
# 303     True
# 304     True
# 305     True
# 306     True
# 307    False
# 308     True
# 309     True
# 310    False
# 311     True
# 312    False
# 313    False
# 314     True
# 315     True
# 316     True
# 317     True
# 318     True
# 319     True
# 320     True
# 321     True
# 322     True
# 323     True
# 324     True
# 325     True
# 326     True
# 327     True
# 328     True
# 329     True
# 330    False
# 331    False
# Length: 332, dtype: bool

# %%
uniquser=kazi.drop_duplicates(["username"])
uniquser
# Out:
#                Timestamp                                         Tweet_text  \
# 0    2019-05-22 08:52:11  Information Technology Intern at Save the Chil...
# 1    2019-05-22 08:50:38  OFFER! OFFER! OFFER! Get websites for corporat...
# 2    2019-05-22 08:28:26  A brother is looking for internship opportunit...
# 3    2019-05-22 07:00:00  #IkoKazi New!! Konza Technopolis Job Opportuni...
# 4    2019-05-22 06:46:53  .#IkoKaziKE Last day to apply... Role: Resourc...
# 5    2019-05-22 06:45:03  We are hiring!! We are looking for a nurse to ...
# 6    2019-05-22 06:26:00  Looking for someone who has a sales and market...
# 7    2019-05-22 06:25:35                  @IEBCKenya @B_E_N_J_A_H  #ikokazi
# 11   2019-05-22 05:31:51  Make your memorable event photos permanent by ...
# 12   2019-05-22 04:56:59        #IkoKaziKE #IkoKazi https://t.co/NY9MyTEHA5
# 14   2019-05-22 04:47:21  Administration Intern. https://t.co/ssvL9pFbdH...
# ...

# %%
uniquser[["username"]][0:30]
# Out:
#               username
# 0       b'campusbizKE'
# 1   b'JamiiWebdesigns'
# 2      b'hussein_amed'
# 3     b'CareerPointKe'
# 4        b'ke_British'
# 5    b'Makini_Schools'
# 6        b'Ayshahmshe'
# 7       b'patt_kyaloh'
# 11      b'shaddydavid'
# 12     b'RamsaLimited'
# 14     b'WiseMonkeyKE'
# 17      b'jillo_jillo'
# 18    b'hustonmalande'
# 19     b'edith_jeruto'
# 20         b'Kajoe254'
# 21        b'AmosKRuto'
# 22       b'edge_Kenya'
# 23     b'dennisobed70'
# 24        b'grey_were'
# 25        b'NellyKipt'
# 26      b'360_laundry'
# 27        b'njengaliz'
# 29        b'mr_ryan_n'
# 34   b'Alvinmwangi254'
# 35   b'bvaletservices'
# 36       b'Kaizasouze'
# 38         b'spartexy'
# 39  b'WabwobaConsolat'
# 40      b'DorbeleitHR'
# 41  b'sheffield_afric'

# %%
user_name=uniquser.username.str.replace("b'","").str.replace("'","")
user_name.str.capitalize()
# Out:
# 0          Campusbizke
# 1      Jamiiwebdesigns
# 2         Hussein_amed
# 3        Careerpointke
# 4           Ke_british
# 5       Makini_schools
# 6           Ayshahmshe
# 7          Patt_kyaloh
# 11         Shaddydavid
# 12        Ramsalimited
# 14        Wisemonkeyke
# 17         Jillo_jillo
# 18       Hustonmalande
# 19        Edith_jeruto
# 20            Kajoe254
# 21           Amoskruto
# 22          Edge_kenya
# 23        Dennisobed70
# 24           Grey_were
# 25           Nellykipt
# 26         360_laundry
# 27           Njengaliz
# 29           Mr_ryan_n
# 34      Alvinmwangi254
# 35      Bvaletservices
# 36          Kaizasouze
# 38            Spartexy
# 39     Wabwobaconsolat
# 40         Dorbeleithr
# 41     Sheffield_afric
#             ...
# 195    Prestigesafemo1
# 207     Slaydoll_store
# 208         Its_maxwel
# 219     Alternatedoors
# 224        Tuvibekenya
# 225            Muyah10
# 229    Abillonstartups
# 230     Rotichbenard15
# 231          P_gichuki
# ...

# %%
# Total number of active usernames
user_name.count()
# Out:
# 105

# %%
kazi.username.mode()
# username with high postings
# Out:
# 0    b'campusbizKE'
# dtype: object

# %%
# Usernames with the highest number of postings
frequented = kazi.username.str.replace("b'","").str.replace("'","").value_counts()
frequented.head()
# Out:
# campusbizKE      120
# KenyanTimes01     32
# Finance_501       26
# CareerPointKe      9
# WiseMonkeyKE       6
# Name: username, dtype: int64

# %%
# username postings in descending order
frequented[0:40]
# Out:
# campusbizKE        120
# KenyanTimes01       32
# Finance_501         26
# CareerPointKe        9
# WiseMonkeyKE         6
# BuuPass              4
# wambua69             4
# spartexy             4
# shaddydavid          4
# WabwobaConsolat      3
# KeVacancies          3
# QSSKenya             3
# SamNdunguz           3
# kyobidigital         3
# RamsaLimited         3
# alternateFX          2
# slaydollmua          2
# Samhinagencies       2
# mmijikenda           2
# alternatedoors       2
# fuzu                 2
# ChefRobertKE         2
# SirBobz              2
# Maganakenyatta       2
# hustonmalande        2
# Anquick_254          2
# slaydoll_store       2
# edge_Kenya           2
# Muyah10              2
# Oduor_Kweje          2
# ke_British           1
# obibeats             1
# sheffield_afric      1
# grade1bales          1
# HarlimSagwa          1
# Digital4Africa       1
# bvaletservices       1
# kevbrownoh           1
# CrucialPoetar        1
# mr_ryan_n            1
# ...

# %%
# bar chart showing top five username posting
ax = frequented.head().plot(kind='bar',
                                    figsize=(16,8),
                                    title="TOP 5 USER POSTINGS")
ax.set_xlabel("Username")
ax.set_ylabel("Number of Postings")
plt.show()

# %%
# Jobs being posted & what people are asking for are analysed below:

# %%
apply=kazi[kazi.Tweet_text.str.contains("APPLY|Apply|aplly")]
apply[['Tweet_text','username']]
# Out:
#                                             Tweet_text          username
# 0    Information Technology Intern at Save the Chil...    b'campusbizKE'
# 3    #IkoKazi New!! Konza Technopolis Job Opportuni...  b'CareerPointKe'
# 8    CLOSING TODAY: Applications for Research Assis...    b'campusbizKE'
# 9    CLOSING TODAY: Applications for UN-Habitat Urb...    b'campusbizKE'
# 10   DEADLINE DAY: Applications for UNICEF Youth Ad...    b'campusbizKE'
# 13   CLOSING TODAY: Applications for Data Engineer ...    b'campusbizKE'
# 15   CLOSING TODAY: Applications for UN-Habitat Was...    b'campusbizKE'
# 16   HAVE YOU SUBMITTED YOUR APPLICATION FOR Electr...    b'campusbizKE'
# 28   Graduate Engineer Trainee Vacancies at Sheffie...    b'campusbizKE'
# 30   Front Office Intern at Legibra  How to Apply &...    b'campusbizKE'
# 31   Office Assistant Vacancy at Balozi Sacco  How ...    b'campusbizKE'
# 32   Tours and Travel Consultant Intern at Elective...    b'campusbizKE'
# ...

# %%
app=apply.Tweet_text.count().astype(float)
app
# Out:
# 137.0

# %%
experi=kazi[kazi.Tweet_text.str.contains("Experience|experience|EXPERIENCE|experienced")]
experi[['Tweet_text','username']]
# Out:
#                                             Tweet_text           username
# 23   I am highly experienced in Gold dealings. I am...    b'dennisobed70'
# 208  Hi guys anyone of you here who knows a company...      b'its_maxwel'
# 307  We're hiring!! We are looking for an experienc...  b'Digital4Africa'

# %%
internship=kazi[kazi.Tweet_text.str.contains("Intern|intern|internship")]
internship[['Tweet_text','followers']]
# Out:
#                                             Tweet_text  followers
# 0    Information Technology Intern at Save the Chil...      12721
# 2    A brother is looking for internship opportunit...        282
# 9    CLOSING TODAY: Applications for UN-Habitat Urb...      12721
# 10   DEADLINE DAY: Applications for UNICEF Youth Ad...      12721
# 14   Administration Intern. https://t.co/ssvL9pFbdH...        261
# 15   CLOSING TODAY: Applications for UN-Habitat Was...      12721
# 30   Front Office Intern at Legibra  How to Apply &...      12721
# 32   Tours and Travel Consultant Intern at Elective...      12721
# 36   Hello #KOT,   I have a needy Uni student who's...        699
# 37   Sales &amp; Marketing Intern https://t.co/diY0...        261
# 44   APPLICATIONS DEADLINE DAY: Sonographer Interns...      12721
# 45   CLOSING TODAY: Applications for Internships at...      12721
# 48   CLOSING TODAY: Applications for Sub Editor Int...      12721
# ...

# %%
# Total number of posts regarding the intern post
interr=internship.Tweet_text.count().astype(float)
interr
# Out:
# 78.0

# %%
raw_dat = {'Job': ['Assistant','Marketing', 'Finance','HR', 'Developer'],
        'Times': [46,12,30,5,11]}
        
dfl = pd.DataFrame(raw_dat, columns = ['Job', 'Times'])
dfl
# Out:
#          Job  Times
# 0  Assistant     46
# 1  Marketing     12
# 2    Finance     30
# 3         HR      5
# 4  Developer     11

# %%
# Create a list of colors (from iWantHue)
colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B", "#EB8076", "#96624E"]

# Create a pie chart
plt.pie(
    # using data total)arrests
    dfl['Times'],
    # with the labels being officer names
    labels=dfl['Job'],
    # with no shadows
    shadow=False,
    # with colors
    colors=colors,
    # with one slide exploded out
#     explode=(0, 0, 0, 0, 0.15),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %%
assis=kazi[kazi.Tweet_text.str.contains("Assistant|assistant")]
assis.style.set_properties(subset=['Tweet_text'], **{'width': '1500px'})
# Out:
# <style  type="text/css" >
#     #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow0_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow1_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow2_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow3_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow4_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow5_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow6_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow7_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow8_col1 {
#             width:  1500px;
#         }    #T_bcc93824_8200_11e9_914e_a0a8cdb237fcrow9_col1 {
#             width:  1500px;
# ...

# %%
here=kazi[kazi.Tweet_text.str.contains(" *HR")]
# here.head()
here.style.set_properties(subset=['Tweet_text'], **{'width': '1500px'})
# Out:
# <style  type="text/css" >
#     #T_75569780_81ff_11e9_914e_a0a8cdb237fcrow0_col1 {
#             width:  1500px;
#         }    #T_75569780_81ff_11e9_914e_a0a8cdb237fcrow1_col1 {
#             width:  1500px;
#         }    #T_75569780_81ff_11e9_914e_a0a8cdb237fcrow2_col1 {
#             width:  1500px;
#         }    #T_75569780_81ff_11e9_914e_a0a8cdb237fcrow3_col1 {
#             width:  1500px;
#         }    #T_75569780_81ff_11e9_914e_a0a8cdb237fcrow4_col1 {
#             width:  1500px;
#         }    #T_75569780_81ff_11e9_914e_a0a8cdb237fcrow5_col1 {
#             width:  1500px;
#         }</style><table id="T_75569780_81ff_11e9_914e_a0a8cdb237fc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Timestamp</th>        <th class="col_heading level0 col1" >Tweet_text</th>        <th class="col_heading level0 col2" >username</th>        <th class="col_heading level0 col3" >followers</th>    </tr></thead><tbody>
# ...

# %%
here.Tweet_text.count()
# Out:
# 6

# %%
# Total number of posts regarding the assistant post
assis.Tweet_text.count()
# Out:
# 46

# %%
market=kazi[kazi.Tweet_text.str.contains('Marketing|marketing')]
market
# Out:
#                Timestamp                                         Tweet_text  \
# 6    2019-05-22 06:26:00  Looking for someone who has a sales and market...
# 37   2019-05-21 08:50:35  Sales &amp; Marketing Intern https://t.co/diY0...
# 132  2019-05-17 10:06:02  We are looking for a communication Professiona...
# 160  2019-05-16 12:29:20  I used my Graphic Design skills to come up wit...
# 176  2019-05-16 08:01:16  Telesales &amp; Marketing Internship at Jobsik...
# 184  2019-05-16 05:18:00  CLOSING TODAY: Applications for Marketing Inte...
# 185  2019-05-16 05:04:00  JOB | Trade Marketing Manager - Modern Trade |...
# 192  2019-05-15 15:00:01  #IkoKazi Communication &amp; Marketing Job. Ut...
# 197  2019-05-15 10:50:28  Kyobi Digital takes great value in executing e...
# 223  2019-05-15 04:58:00  CLOSING TODAY: Applications for Marketing Assi...
# 315  2019-05-13 05:50:00  CLOSING TODAY: Applications for Junior Marketi...
#
#              username  followers
# ...

# %%
# Total number of posts regarding the marketing post
market.Tweet_text.count()
# Out:
# 11

# %%
vacancy = kazi[kazi.Tweet_text.str.contains("Credit|Finance")]
vacancy.head()
# Out:
#               Timestamp                                         Tweet_text  \
# 75  2019-05-20 05:16:00  APPLICATIONS DEADLINE DAY: Finance and Credit ...
# 77  2019-05-20 05:03:00  JOB | Senior Commercial Finance Manager | @Bat...
# 78  2019-05-20 05:02:00  JOB | Accountant | @CentumPLC | Ol Kalou, Nyan...
# 89  2019-05-19 10:38:14  UN-Habitat Finance and Budget Internship  How ...
# 91  2019-05-19 09:13:10  Finance and Credit Assistant Vacancy at Red Do...
#
#           username  followers
# 75  b'campusbizKE'      12721
# 77  b'Finance_501'       1078
# 78  b'Finance_501'       1078
# 89  b'campusbizKE'      12721
# 91  b'campusbizKE'      12721

# %%
# Total number of posts regarding the credit and finance post
vacancy.Tweet_text.count()
# Out:
# 30

# %%
dire_need_of_a_job = kazi[kazi.Tweet_text.str.contains("look|looking")]
dire_need_of_a_job
# Out:
#                Timestamp                                         Tweet_text  \
# 2    2019-05-22 08:28:26  A brother is looking for internship opportunit...
# 5    2019-05-22 06:45:03  We are hiring!! We are looking for a nurse to ...
# 26   2019-05-21 11:16:26  We are looking for a lady ages 20 to 25 years ...
# 35   2019-05-21 08:59:13  Do you have a spot for valet jobs,Bvalet is lo...
# 39   2019-05-21 07:36:11  Hi guys, I'm looking for a job. Shop attendant...
# 41   2019-05-21 06:18:41  Grow you career with Sheffield Africa. We are ...
# 61   2019-05-20 10:13:36  #IKOKAZI We are looking for a #competent and #...
# 62   2019-05-20 10:09:49  One of the most crucial mistakes that an upcom...
# 132  2019-05-17 10:06:02  We are looking for a communication Professiona...
# 134  2019-05-17 09:56:05  My Brother is looking for a job. BSc. Mathemat...
# 137  2019-05-17 08:36:10  My Brother is looking for a job. BSc. Mathemat...
# ...

# %%
# Total number of posts of people expressing their 'need for a job' post
lok=dire_need_of_a_job.Tweet_text.count().astype(float)
lok
# Out:
# 27.0

# %%
developer = kazi[kazi.Tweet_text.str.contains("Code|Developer|developer")]
developer
# Out:
#                Timestamp                                         Tweet_text  \
# 76   2019-05-20 05:04:00  DON'T MISS OUT: Apply now for Android Develope...
# 82   2019-05-20 04:55:00  CLOSING TODAY: Applications for Mobile and Web...
# 118  2019-05-17 13:21:35  iOS Developer Intern at the Institute Of Softw...
# 120  2019-05-17 13:01:46  Android Developer Intern at Institute of Softw...
# 140  2019-05-17 07:09:14  @BuuPass, a company working with transport ope...
# 158  2019-05-16 14:24:45  Job Alert!!!! @STLHorizon is looking for:  htt...
# 204  2019-05-15 09:16:20  Junior Bahmni/DHIS2 Developer Vacancies at Int...
# 206  2019-05-15 08:06:21  PHP/Laravel Developer Internship at Rate My Se...
# 261  2019-05-14 06:20:14  Looking for ReactJS developers. JD here: https...
# 262  2019-05-14 06:01:00  CLOSING TODAY: Applications for Software Devel...
# 307  2019-05-13 08:47:40  We're hiring!! We are looking for an experienc...
#
#               username  followers
# ...

# %%
# Total number of posts regarding the developer post
developer.Tweet_text.count().astype(float)
# Out:
# 11.0

# %%
raw_datas = {'Keywords': ['Nairobi', 'Internship', 'Apply', 'looking'],
        'frequency': [14, 69, 85, 132]}
        
df = pd.DataFrame(raw_datas, columns = ['Keywords', 'frequency'])
df
# Out:
#      Keywords  frequency
# 0     Nairobi         14
# 1  Internship         69
# 2       Apply         85
# 3     looking        132

# %%
# labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
# # sizes = [23,45,12,90]
# sizes = ['interr','naro','lok','app']
# # only "explode" the 2nd slice (i.e. 'Hogs')
# explode = (0, 0.1, 0, 0)  
# fig1, ax1 = plt.subplots()
# ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#         shadow=True, startangle=90)
# # Equal aspect ratio ensures that pie is drawn as a circle
# ax1.axis('equal')  
# plt.tight_layout()
# plt.show()


# colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B", "#EB8076", "#96624E"]

# Create a pie chart
# plt.pie(
    # using data total)arrests
#     internship.Tweet_text.count(),nai.Tweet_text.count(),dire_need_of_a_job.Tweet_text.count(),apply.Tweet_text.count() 
#     labels=kazi['officer_name'],
    # with no shadows
#     shadow=False,
    # with colors
#     colors=colors,
    # with one slide exploded out
#     explode=(0, 0, 0, 0, 0.15),
    # with the start angle at 90%
#     startangle=90,
    # with the percent listed as a fraction
#     autopct='%1.1f%%',
#     )

# View the plot drop above
# plt.axis('equal')

# View the plot
# plt.tight_layout()
# plt.show()

# Create a list of colors (from iWantHue)
colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B", "#EB8076", "#96624E"]

# Create a pie chart
plt.pie(
    # using data total)arrests
    df['frequency'],
    # with the labels being officer names
    labels=df['Keywords'],
    # with no shadows
    shadow=False,
    # with colors
    colors=colors,
    # with one slide exploded out
#     explode=(0, 0, 0, 0, 0.15),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %%
# Job locations:

# %%
raw_datass = {'Locations': ['Nairobi','Kisumu', 'Uasin Gishu', 'Nyeri','Nakuru','Eldoret'],
        'Mentions': [31,2,3,6,8,1 ]}
        
dfs = pd.DataFrame(raw_datass, columns = ['Locations', 'Mentions'])
dfs
# Out:
#      Locations  Mentions
# 0      Nairobi        31
# 1       Kisumu         2
# 2  Uasin Gishu         3
# 3        Nyeri         6
# 4       Nakuru         8
# 5      Eldoret         1

# %%
# Create a list of colors (from iWantHue)
colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B", "#EB8076", "#96624E"]

# Create a pie chart
plt.pie(
    # using data total)arrests
    dfs['Mentions'],
    # with the labels being officer names
    labels=dfs['Locations'],
    # with no shadows
    shadow=False,
    # with colors
    colors=colors,
    # with one slide exploded out
#     explode=(0, 0, 0, 0, 0.15),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %%
# Job postings in Nairobi
nai=kazi[kazi.Tweet_text.str.contains('Nairobi|nairobi')]
nai.style.set_properties(subset=['Tweet_text'], **{'width': '1500px'})
# Out:
# <style  type="text/css" >
#     #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow0_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow1_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow2_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow3_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow4_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow5_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow6_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow7_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow8_col1 {
#             width:  1500px;
#         }    #T_cd7b8616_81ee_11e9_914e_a0a8cdb237fcrow9_col1 {
#             width:  1500px;
# ...

# %%
# Job postings in Nairobi
naro = nai.Tweet_text.count().astype(float)
naro
# Out:
# 31.0

# %%
# Job postings in Uasin Gishu
UG=kazi[kazi.Tweet_text.str.contains('Uasin Gishu')]
UG
# Out:
#                Timestamp                                         Tweet_text  \
# 60   2019-05-20 11:00:00  #IkoKazi See Now! Well Paying Companies Hiring...
# 101  2019-05-18 10:30:00  ICYMI: Certificate, Diploma &amp; Degree Gradu...
# 226  2019-05-14 17:51:19  Certificate, Diploma &amp; Degree Graduates In...
#
#              username  followers
# 60   b'CareerPointKe'      18605
# 101    b'campusbizKE'      12721
# 226    b'campusbizKE'      12721

# %%
# Job postings in Uasin Gishu
UG.Tweet_text.count()
# Out:
# 3

# %%
# Job postings in Nyeri
nyeri = kazi[kazi.Tweet_text.str.contains('Nyeri|nyeri')]
nyeri
# Out:
#                Timestamp                                         Tweet_text  \
# 102  2019-05-18 09:25:00  ICYMI: 200 Internship Vacancies at the County ...
# 114  2019-05-17 15:00:00  #IkoKazi Hair Dressing Internship. Nyeri Count...
# 245  2019-05-14 11:21:20  200 Internship Vacancies at the County Governm...
#
#              username  followers
# 102    b'campusbizKE'      12721
# 114  b'CareerPointKe'      18605
# 245    b'campusbizKE'      12721

# %%
# Job postings in Nyeri
nyeri.Tweet_text.count()
# Out:
# 3

# %%
# Job postings in Mombasa
msa = kazi[kazi.Tweet_text.str.contains('mombasa|Mombasa')]
msa
# Out:
#                Timestamp                                         Tweet_text  \
# 159  2019-05-16 14:02:26  Express Shipping &amp; Logistics (EA) LTD is H...
# 297  2019-05-13 12:22:07  Hey guys, i have a 9 seater van for hire. For ...
# 299  2019-05-13 12:07:48  TODAY IS THE DEADLINE: CHIEF ACCOUNTANT POSITI...
#
#               username  followers
# 159         b'samnato'        494
# 297       b'bomberz06'         67
# 299  b'consultants_go'          2

# %%
# Job postings in Mombasa
msa.Tweet_text.count()
# Out:
# 3

# %%
# Job postings in Eldoret
nku = kazi[kazi.Tweet_text.str.contains('Eldoret|eldoret')]
nku
# Out:
#                Timestamp                                         Tweet_text  \
# 116  2019-05-17 13:52:56  Looking for decent @Airbnb in kisumu, and eldo...
#
#               username  followers
# 116  b'Maganakenyatta'       3308

# %%
# Job postings in Kisumu
ksm = kazi[kazi.Tweet_text.str.contains('Kisumu|kisumu')]
ksm
# Out:
#                Timestamp                                         Tweet_text  \
# 5    2019-05-22 06:45:03  We are hiring!! We are looking for a nurse to ...
# 116  2019-05-17 13:52:56  Looking for decent @Airbnb in kisumu, and eldo...
#
#               username  followers
# 5    b'Makini_Schools'        715
# 116  b'Maganakenyatta'       3308
